# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/Physics3/blob/master/STEM/4_3_2_%E7%AD%89%E9%9B%BB%E4%BD%8D%E9%9D%A2_%E9%9B%BB%E4%BD%8D_%E7%89%A9%E7%90%863.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 電位

# %% [markdown]
# ## 等電位面

# %%
#@title 等電位面を書いてみよう
# %%html
<iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
#  > Q. 次のような等電位面を上のアプレット上に作成して下さい。
#
# ![](https://phys.libretexts.org/@api/deki/files/8126/CNX_UPhysics_24_05_EqOpp.jpg?revision=1)
#
# ---
#
# 出典 [7.6: Equipotential Surfaces and Conductors, https://phys.libretexts.org/](https://phys.libretexts.org/Bookshelves/University_Physics/Book%3A_University_Physics_(OpenStax)/Map%3A_University_Physics_II_-_Thermodynamics_Electricity_and_Magnetism_(OpenStax)/07%3A_Electric_Potential/7.06%3A_Equipotential_Surfaces_and_Conductors)

# %% [markdown]
#  > Q. 次のような等電位面を上のアプレット上に作成して下さい。
#
# ![](https://phys.libretexts.org/@api/deki/files/8126/CNX_UPhysics_24_05_EqOpp.jpg?revision=1)
#
# ---
#
# 出典 [7.6: Equipotential Surfaces and Conductors, https://phys.libretexts.org/](https://phys.libretexts.org/Bookshelves/University_Physics/Book%3A_University_Physics_(OpenStax)/Map%3A_University_Physics_II_-_Thermodynamics_Electricity_and_Magnetism_(OpenStax)/07%3A_Electric_Potential/7.06%3A_Equipotential_Surfaces_and_Conductors)

# %% [markdown]
# <!--
# > Q. 次のような等電位面を上のアプレット上に作成して下さい。
#
# ![](https://phys.libretexts.org/@api/deki/files/8127/CNX_UPhysics_24_05_EqSame.jpg?revision=1)
#
# ---
#
# 出典 [7.6: Equipotential Surfaces and Conductors, https://phys.libretexts.org/](https://phys.libretexts.org/Bookshelves/University_Physics/Book%3A_University_Physics_(OpenStax)/Map%3A_University_Physics_II_-_Thermodynamics_Electricity_and_Magnetism_(OpenStax)/07%3A_Electric_Potential/7.06%3A_Equipotential_Surfaces_and_Conductors)-->

# %% [markdown]
# ### 等電位面の３次元図

# %%
# %%html
# https://phys.libretexts.org/Bookshelves/Ancillary_Materials/Visualizations_and_Simulations/CalcPlot3D_Interactive_Figures/Physics_Figures/Figure_7.5.4_Electric_Potential_Map_II
# Out:
# <!DOCTYPE html>
# <html  lang="en">
# <head prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#">
#
#         <meta name="viewport" content="width=device-width, initial-scale=1"/>
#         <meta name="google-site-verification" content="ej-DagC8sD_MaouJikcyiz-sulM4oKdtg95K_XZJLjc"/>
#         <meta name="google-site-verification" content="rSShJ5luwHFhTK8E6UL7I0y65IzBdmjPYUzzfytGlfY"/>
#         <meta name="msvalidate.01" content="A926216166C5BBBA69471D90C323176E"/>
#         <meta name="msvalidate.01" content="B0640A1D6F3CE71B69FA9E740730577C"/>
#         <meta name="generator" content="MindTouch"/>
#         <meta name="robots" content="index,follow"/>
#         <meta property="og:title" content="Figure 7.5.4 Electric Potential Map II"/>
#         <meta property="og:site_name" content="Physics LibreTexts"/>
#         <meta property="og:type" content="article"/>
#         <meta property="og:locale" content="en_US"/>
# ...

# %% [markdown]
# >Q 教科書 下巻 p64 図4.22 と３次元図を比較して下さい.

# %%
#@title 等電位面と電気力線の交わり
# %%html
<iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>
# Out:
# <iframe src="https://phet.colorado.edu/sims/html/charges-and-fields/latest/charges-and-fields_en.html" width="600" height="450" scrolling="no" allowfullscreen></iframe>

# %% [markdown]
# > Q. 等電位面と電気力線の交わる角度はいくらか?
